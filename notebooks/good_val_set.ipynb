# %%
from datasets import load_from_disk
from pathlib import Path
import matplotlib.pyplot as plt

# %%
project_root = Path.cwd().parent
data_path_test = project_root / "data" / "test"
data_path_validation = project_root / "data" / "validation"
data_path_train = project_root / "data" / "train"

dataset = load_from_disk(str(data_path_validation))

# %% [markdown]
# Fehlende Daten überprüfen

# %%
import pandas as pd
from pathlib import Path
from datasets import load_from_disk

# Beispiel: Lade den Validation-Datensatz
project_root = Path.cwd().parent
data_path_validation = project_root / "data" / "validation"
dataset = load_from_disk(str(data_path_validation))
df = dataset.to_pandas()

# 1. Überblick über fehlende Werte (NaN) pro Spalte
print("Missing Values Summary:")
print(df.isnull().sum())

# 2. Überprüfe auf leere Strings in wichtigen Spalten (z. B. question, answer, image)
# Dies kann zusätzlich zu NaN wertvoll sein, falls leere Strings als fehlende Angaben kodiert sind.
critical_columns = ["question", "answer", "image"]
empty_counts = df[critical_columns].apply(lambda x: (x == "").sum())
print("\nEmpty Strings Summary:")
print(empty_counts)

# 3. Zeige Zeilen an, in denen in mindestens einer der kritischen Spalten fehlende oder leere Werte vorliegen
missing_or_empty = df[critical_columns].isnull() | (df[critical_columns] == "")
rows_with_issues = df[missing_or_empty.any(axis=1)]
print("\nRows with Missing or Empty Critical Fields:")
print(rows_with_issues)

# 4. Optional: Eine kurze Statistik, wie groß der Anteil fehlender oder unvollständiger Daten ist
total_rows = len(df)
num_incomplete = len(rows_with_issues)
print(f"\nInsgesamt {num_incomplete} von {total_rows} Zeilen ({num_incomplete/total_rows*100:.1f}%) weisen fehlende oder unvollständige Daten in den kritischen Feldern auf.")
# Out:
# Missing Values Summary:
# image       0
# question    0
# answer      0
# dtype: int64
#
# Empty Strings Summary:
# question    0
# answer      0
# image       0
# dtype: int64
#
# Rows with Missing or Empty Critical Fields:
# Empty DataFrame
# Columns: [image, question, answer]
# Index: []
#
# Insgesamt 0 von 6259 Zeilen (0.0%) weisen fehlende oder unvollständige Daten in den kritischen Feldern auf.

# %% [markdown]
# Frage- und Antwortenlänge analysieren

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from datasets import load_from_disk

# 1. Lade die Datensätze aus Train, Validation und Test
project_root = Path.cwd().parent
data_path_train = project_root / "data" / "train"
data_path_validation = project_root / "data" / "validation"
data_path_test = project_root / "data" / "test"

dataset_train = load_from_disk(str(data_path_train))
dataset_val = load_from_disk(str(data_path_validation))
dataset_test = load_from_disk(str(data_path_test))

# 2. Wandle die Datensätze in Pandas DataFrames um
df_train = dataset_train.to_pandas()
df_val = dataset_val.to_pandas()
df_test = dataset_test.to_pandas()

# 3. Führe alle DataFrames zu einem einzigen DataFrame zusammen
df_all = pd.concat([df_train, df_val, df_test], ignore_index=True)

# 4. Berechne die Länge von Fragen und Antworten

# Länge in Wörtern
df_all['question_length_words'] = df_all['question'].apply(lambda x: len(x.split()))
df_all['answer_length_words'] = df_all['answer'].apply(lambda x: len(x.split()))

# Länge in Zeichen
df_all['question_length_chars'] = df_all['question'].apply(len)
df_all['answer_length_chars'] = df_all['answer'].apply(len)

# 5. Ausgabe von statistischen Kennzahlen
print("Statistik zur Wortanzahl in Fragen:")
print(df_all['question_length_words'].describe())
print("\nStatistik zur Wortanzahl in Antworten:")
print(df_all['answer_length_words'].describe())

print("\nStatistik zur Zeichenanzahl in Fragen:")
print(df_all['question_length_chars'].describe())
print("\nStatistik zur Zeichenanzahl in Antworten:")
print(df_all['answer_length_chars'].describe())

# 6. Visualisierung: Histogramme für Wortlängen
plt.figure(figsize=(12, 5))
plt.hist(df_all['question_length_words'], bins=50, alpha=0.7, label='Fragen (Wörter)')
plt.hist(df_all['answer_length_words'], bins=50, alpha=0.7, label='Antworten (Wörter)')
plt.xlabel('Anzahl Wörter')
plt.ylabel('Häufigkeit')
plt.title('Verteilung der Wortanzahl in Fragen und Antworten')
plt.legend()
plt.show()

# 7. Visualisierung: Histogramme für Zeichenlängen
plt.figure(figsize=(12, 5))
plt.hist(df_all['question_length_chars'], bins=50, alpha=0.7, label='Fragen (Zeichen)')
plt.hist(df_all['answer_length_chars'], bins=50, alpha=0.7, label='Antworten (Zeichen)')
plt.xlabel('Anzahl Zeichen')
plt.ylabel('Häufigkeit')
plt.title('Verteilung der Zeichenanzahl in Fragen und Antworten')
plt.legend()
plt.show()
# Out:
# Statistik zur Wortanzahl in Fragen:
# count    32632.000000
# mean         6.230633
# std          4.505474
# min          2.000000
# 25%          3.000000
# 50%          5.000000
# 75%          8.000000
# max         42.000000
# Name: question_length_words, dtype: float64
#
# Statistik zur Wortanzahl in Antworten:
# count    32632.000000
# mean         1.784629
# std          2.225789
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         34.000000
# Name: answer_length_words, dtype: float64
#
# Statistik zur Zeichenanzahl in Fragen:
# count    32632.000000
# mean        39.750123
# std         31.333123
# min          8.000000
# 25%         16.000000
# 50%         26.000000
# 75%         51.000000
# max        264.000000
# Name: question_length_chars, dtype: float64
#
# Statistik zur Zeichenanzahl in Antworten:
# count    32632.000000
# mean        10.760695
# std         16.203600
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%         13.000000
# max        220.000000
# Name: answer_length_chars, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 46
#      44 text = row["question"] + " " + row["answer"]
#      45 try:
# ---> 46     terms = extract_fachbegriffe_from_text(text)
#      47     all_terms.extend(terms)
#      48 except Exception as e:
#
# Cell In[7], line 16, in extract_fachbegriffe_from_text(text)
#      12 def extract_fachbegriffe_from_text(text):
#      13     """
#      14     Extrahiert aus einem Text alle Noun Chunks (mehrwörtige Phrasen) als potenzielle Fachbegriffe.
#      15     """
# ---> 16     doc = nlp(text)
#      17     # Noun chunks, die mehr als ein Wort enthalten
#      18     terms = [chunk.text.lower() for chunk in doc.noun_chunks if len(chunk.text.split()) > 1]
#
# File ~\Desktop\BA\BA\Bachelor_Arbeit_VQA\venv\Lib\site-packages\spacy\language.py:1052, in Language.__call__(self, text, disable, component_cfg)
#    1050     error_handler = proc.get_error_handler()
#    1051 try:
# -> 1052     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1053 except KeyError as e:
#    1054     # This typically happens if a component is not initialized
#    1055     raise ValueError(Errors.E109.format(name=name)) from e
#
# File ~\Desktop\BA\BA\Bachelor_Arbeit_VQA\venv\Lib\site-packages\spacy\pipeline\trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# File ~\Desktop\BA\BA\Bachelor_Arbeit_VQA\venv\Lib\site-packages\spacy\pipeline\transition_parser.pyx:264, in spacy.pipeline.transition_parser.Parser.predict()
#
# File ~\Desktop\BA\BA\Bachelor_Arbeit_VQA\venv\Lib\site-packages\spacy\pipeline\transition_parser.pyx:285, in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# File ~\Desktop\BA\BA\Bachelor_Arbeit_VQA\venv\Lib\site-packages\thinc\model.py:334, in Model.predict(self, X)
#     330 def predict(self, X: InT) -> OutT:
#     331     """Call the model's `forward` function with `is_train=False`, and return
#     332     only the output, instead of the `(output, callback)` tuple.
#     333     """
# --> 334     return self._func(self, X, is_train=False)[0]
#
# File ~\Desktop\BA\BA\Bachelor_Arbeit_VQA\venv\Lib\site-packages\spacy\ml\tb_framework.py:34, in forward(model, X, is_train)
#      33 def forward(model, X, is_train):
# ---> 34     step_model = ParserStepModel(
#      35         X,
#      36         model.layers,
#      37         unseen_classes=model.attrs["unseen_classes"],
#      38         train=is_train,
#      39         has_upper=model.attrs["has_upper"],
#      40     )
#      42     return step_model, step_model.finish_steps
#
# File ~\Desktop\BA\BA\Bachelor_Arbeit_VQA\venv\Lib\site-packages\spacy\ml\parser_model.pyx:250, in spacy.ml.parser_model.ParserStepModel.__init__()
#
# File ~\Desktop\BA\BA\Bachelor_Arbeit_VQA\venv\Lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~\Desktop\BA\BA\Bachelor_Arbeit_VQA\venv\Lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# KeyboardInterrupt:

# %% [markdown]
# # Fragentypen analysieren

# %%
import re
import pandas as pd
from pathlib import Path
from datasets import load_from_disk

def get_question_type(question):
    """
    Bestimmt den Fragetyp anhand des ersten Wortes der Frage.
    - Wenn das erste Wort ein typisches Fragewort (z. B. What, Where, When, How, Why, Who, Whom, Which) ist,
      wird genau dieses (capitalized) zurückgegeben.
    - Wenn das erste Wort ein Hilfsverb ist (z. B. is, are, do, etc.), wird "Yes/No" zurückgegeben.
    - Andernfalls wird "Other" zurückgegeben.
    """
    q = question.strip().lower()
    match = re.match(r"(\w+)", q)
    if match:
        first_word = match.group(1)
        interrogatives = {"what", "where", "when", "how", "why", "who", "whom", "which"}
        if first_word in interrogatives:
            return first_word.capitalize()
        auxiliaries = {"is", "are", "do", "does", "did", "can", "could", "would", "will", "have", "has", "had", "am"}
        if first_word in auxiliaries:
            return "Yes/No"
        return "Other"
    else:
        return "Unknown"

# Definiere die Pfade zu den Datensätzen
project_root = Path.cwd().parent
data_path_train = project_root / "data" / "train"
data_path_validation = project_root / "data" / "validation"
data_path_test = project_root / "data" / "test"

# Lade die Datensätze (angenommen, sie wurden bereits mit load_from_disk gespeichert)
dataset_train = load_from_disk(str(data_path_train))
dataset_val = load_from_disk(str(data_path_validation))
dataset_test = load_from_disk(str(data_path_test))

# Wandle die Datensätze in Pandas DataFrames um
df_train = dataset_train.to_pandas()
df_val = dataset_val.to_pandas()
df_test = dataset_test.to_pandas()

# Führe alle DataFrames zusammen
df_all = pd.concat([df_train, df_val, df_test], ignore_index=True)

# Bestimme den Fragetyp für jede Frage
df_all["question_type"] = df_all["question"].apply(get_question_type)

# Gruppiere nach Fragetyp und berechne Anzahl und prozentualen Anteil
summary = df_all.groupby("question_type")["question"].agg(["count"]).reset_index()
total = summary["count"].sum()
summary["percentage"] = (summary["count"] / total * 100).round(1)
summary = summary.sort_values("count", ascending=False)

print("Fragetypen im gesamten Datensatz:")
print(summary)
# Out:
# Fragetypen im gesamten Datensatz:
#   question_type  count  percentage
# 7        Yes/No  16194        49.6
# 2          What  13337        40.9
# 4         Where   2155         6.6
# 0           How    695         2.1
# 6           Why    114         0.3
# 1         Other     86         0.3
# 3          When     49         0.2
# 5           Who      2         0.0

# %% [markdown]
# # Neuer Val Datensatz mit 2000 Einträgen

# %%
import pandas as pd
from pathlib import Path
from datasets import load_from_disk

# Heuristische Funktion, um den Fragetyp anhand der Frage zu bestimmen
def get_question_type(question):
    q = question.strip().lower()
    # Zuerst typische Fragewörter
    if q.startswith("what"):
        return "What"
    elif q.startswith("where"):
        return "Where"
    elif q.startswith("when"):
        return "When"
    elif q.startswith("how much") or q.startswith("how many"):
        return "How much/How many"
    elif q.startswith("how"):
        return "How"
    elif q.startswith("why"):
        return "Why"
    elif q.startswith("who"):
        return "Who"
    # Typische Yes/No-Anfangswörter
    yes_no_words = ("is", "are", "do", "does", "did", "can", "could", "would", "will", "have", "has", "had", "am")
    if q.startswith(yes_no_words):
        return "Yes/No"
    return "Other"

# Pfad zum Validation-Datensatz
project_root = Path.cwd().parent
data_path_validation = project_root / "data" / "validation"

# Datensatz laden
dataset = load_from_disk(str(data_path_validation))
df_val = dataset.to_pandas()

# Falls noch nicht vorhanden, berechne den Fragetyp für jede Frage
if "question_type" not in df_val.columns:
    df_val["question_type"] = df_val["question"].apply(get_question_type)

# Gewünschte Verteilung (in Prozenten) aus deiner Analyse:
distribution = {
    "Yes/No": 49.6,
    "What": 40.9,
    "Where": 6.6,
    "How": 2.1,
    "Why": 0.3,
    "Other": 0.3,
    "When": 0.2,
    "Who": 0.0
}

total_new = 2000

# Berechne gewünschte Anzahl pro Fragetyp
desired_counts = {typ: int(round(total_new * perc / 100)) for typ, perc in distribution.items()}
print("Gewünschte Anzahl pro Fragetyp:")
for typ, count in desired_counts.items():
    print(f"{typ}: {count}")

# Stratifiziertes Sampling pro Fragetyp
samples = []
for typ, desired in desired_counts.items():
    group = df_val[df_val["question_type"] == typ]
    if desired > 0:
        if len(group) >= desired:
            sampled = group.sample(n=desired, random_state=42)
        else:
            print(f"Warnung: Gruppe '{typ}' hat nur {len(group)} Einträge. Verwende alle Einträge.")
            sampled = group
        samples.append(sampled)
    # Falls desired 0 ist, überspringen wir den Typ

# Zusammenführen und mischen
new_df = pd.concat(samples).sample(frac=1, random_state=42).reset_index(drop=True)
print(f"\nNeuer Datensatz hat {len(new_df)} Einträge.")

# Zeige die Verteilung im neuen Datensatz
new_distribution = new_df["question_type"].value_counts(normalize=True) * 100
print("\nVerteilung im neuen Datensatz (in %):")
print(new_distribution.sort_index())

# Optional: Speichere den neuen Datensatz als CSV
output_path = project_root / "data" / "validation_subset_2000.csv"
new_df.to_csv(output_path, index=False, quoting=1)  # quoting=1 entspricht csv.QUOTE_ALL
print(f"\nNeuer Datensatz wurde unter {output_path} gespeichert.")

# %%
# Out:
# Gewünschte Anzahl pro Fragetyp:
# Yes/No: 992
# What: 818
# Where: 132
# How: 42
# Why: 6
# Other: 6
# When: 4
# Who: 0
#
# Der neu erstellte Subdatensatz hat 2000 Einträge.
#
# Ausgewählte Original-Indizes:
# [921, 4681, 662, 5810, 6182, 1938, 4280, 2759, 6098, 4728, 3405, 2828, 1473, 5263, 1012, 1306, 2602, 3268, 3550, 5771, 3679, 3657, 2857, 1794, 351, 3632, 581, 1318, 5545, 3384, 6253, 2134, 5734, 4006, 1217, 3929, 415, 563, 100, 4549, 2797, 5844, 3606, 57, 6070, 137, 881, 3662, 3766, 5660, 3380, 1746, 5286, 554, 4925, 4507, 5970, 1832, 4579, 3458, 116, 1393, 697, 3167, 1412, 5325, 3381, 1749, 123, 2876, 3553, 2268, 5524, 3702, 895, 744, 3299, 2735, 6185, 4670, 2832, 4241, 264, 4461, 3493, 154, 3614, 519, 3564, 2417, 2479, 1176, 379, 6238, 2840, 948, 2394, 4075, 5468, 781, 736, 3974, 4100, 1342, 2414, 2861, 1168, 5998, 2032, 6114, 2438, 2722, 2348, 4193, 3032, 3138, 1220, 4003, 6081, 5262, 1139, 468, 4319, 4256, 3343, 4109, 3507, 346, 2331, 2533, 5673, 974, 6257, 3189, 2314, 2180, 1747, 2555, 1810, 2374, 4010, 3174, 4005, 3366, 4453, 1288, 1731, 1308, 6165, 103, 515, 609, 5139, 5012, 877, 826, 680, 2422, 76, 1118, 4177, 1164, 2463, 1664, 4170, 931, 4208, 741, 2981, 1443, 6235, 496, 5507, 5083, 4481, 391, 5659, 3660, 5684, 2693, 4919, 3283, 5497, 3556, 5707, 5917, 5875, 3726, 1140, 2513, 5126, 1719, 2930, 698, 3393, 2244, 6162, 3885, 5214, 1489, 5560, 3106, 2285, 5637, 5268, 696, 6116, 1062, 523, 46, 2118, 4667, 897, 591, 5568, 939, 4120, 3499, 5500, 1906, 1683, 5977, 1799, 372, 1174, 5378, 4626, 5448, 5857, 2743, 5775, 6151, 830, 5646, 1184, 5903, 3706, 4283, 2459, 3626, 981, 1407, 1554, 433, 4510, 2378, 4979, 1576, 4920, 5186, 3038, 4097, 3184, 5896, 4665, 6194, 2229, 3115, 342, 1519, 4648, 5693, 3940, 5837, 1066, 1540, 2618, 1887, 5111, 1500, 4272, 1413, 2231, 5800, 1525, 1034, 4085, 2056, 6005, 5862, 5242, 2611, 1980, 3196, 1629, 462, 64, 676, 4799, 4119, 3083, 689, 1301, 1670, 973, 4327, 5015, 4674, 4754, 1626, 785, 538, 1641, 3873, 5724, 856, 2748, 586, 2126, 1865, 4423, 4220, 3011, 2891, 1016, 4546, 5125, 4934, 2505, 625, 788, 4995, 4211, 6097, 4445, 507, 5604, 4977, 3992, 3689, 168, 3777, 2225, 5281, 386, 2102, 2584, 876, 1039, 1929, 6228, 5452, 1279, 1408, 4484, 4096, 184, 1000, 1737, 4967, 545, 3904, 518, 383, 6154, 4983, 5222, 343, 5614, 3436, 4617, 884, 482, 2259, 2178, 1567, 219, 5831, 3698, 2752, 1136, 3850, 4081, 326, 2864, 3732, 2580, 2999, 5708, 1022, 6179, 3615, 646, 2270, 2338, 4121, 5641, 733, 4580, 4390, 2388, 848, 5632, 1909, 4348, 2850, 528, 2204, 4153, 5171, 2633, 2209, 4540, 1786, 377, 5674, 28, 3441, 4597, 1252, 2359, 4908, 4605, 5770, 3206, 2442, 917, 648, 2701, 4483, 2202, 3804, 5194, 194, 429, 589, 849, 2361, 730, 3208, 611, 2523, 2632, 3194, 6163, 3855, 2445, 4960, 1550, 537, 1229, 1815, 2804, 1371, 3176, 297, 3444, 5275, 620, 3496, 6174, 962, 4383, 3431, 4716, 886, 5863, 4288, 261, 3075, 4309, 2012, 4785, 105, 4466, 652, 1294, 5443, 4293, 5692, 3846, 6107, 2814, 1882, 4497, 2608, 780, 78, 3165, 2902, 983, 4965, 2411, 5850, 2552, 5372, 4405, 5131, 3126, 388, 1084, 1035, 5505, 6027, 464, 2982, 4759, 2604, 4575, 5064, 3708, 3555, 3603, 3877, 4545, 2514, 3896, 5971, 1959, 3423, 681, 2529, 1852, 1805, 2692, 5345, 3785, 3433, 1382, 3569, 5797, 5538, 1323, 229, 5960, 1858, 1145, 4699, 6056, 1726, 4356, 1950, 1497, 502, 4413, 2369, 5824, 570, 702, 5758, 933, 1600, 2576, 5201, 1031, 5902, 1686, 3934, 4653, 4630, 3335, 390, 3073, 2732, 4284, 3241, 1454, 475, 4735, 783, 5257, 347, 4769, 2085, 483, 2253, 4926, 964, 4930, 4158, 5732, 73, 300, 1420, 5180, 3030, 3254, 817, 561, 2104, 3425, 2183, 4179, 155, 3504, 1873, 1171, 3704, 5778, 2301, 5586, 212, 875, 2842, 950, 172, 4244, 1325, 2201, 539, 3978, 775, 5198, 5978, 2872, 6157, 426, 3572, 5351, 6137, 3391, 2823, 4261, 1019, 2452, 1493, 2276, 1708, 2001, 5972, 1441, 2960, 1088, 4509, 3902, 967, 3388, 2772, 5744, 4249, 3385, 5227, 5864, 2625, 1953, 4437, 5599, 1804, 5922, 4691, 1701, 3447, 4659, 2496, 5433, 5682, 3635, 2972, 1132, 3060, 4142, 3093, 463, 421, 4124, 5486, 562, 1112, 6014, 235, 3599, 5905, 3340, 1884, 3107, 5364, 4207, 5763, 2393, 5203, 5079, 489, 3269, 2536, 2347, 4931, 3039, 195, 749, 5027, 760, 984, 442, 3276, 2283, 5748, 2207, 2751, 4757, 633, 60 ...

# %%
len_selected_indices = len(selected_indices)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 len_selected_indices = len(selected_indices)
# ----> 2 len_selected_indices[0]
#
# TypeError: 'int' object is not subscriptable

# %%
output_indices_file = project_root / "data" / "validation_subset_indices.txt"
with open(output_indices_file, "w", encoding="utf-8") as f:
    for idx in selected_indices:
        f.write(str(idx) + "\n")
print(f"\nDie ausgewählten Indizes wurden unter '{output_indices_file}' gespeichert.")
# Out:
# Die ausgewählten Indizes wurden unter 'C:\Users\Arbnor\Desktop\BA\BA\Bachelor_Arbeit_VQA\data\validation_subset_indices.txt' gespeichert.

# %%
selected_indices
# Out:
# [921,
#  4681,
#  662,
#  5810,
#  6182,
#  1938,
#  4280,
#  2759,
#  6098,
#  4728,
#  3405,
#  2828,
#  1473,
#  5263,
#  1012,
#  1306,
#  2602,
#  3268,
#  3550,
#  5771,
#  3679,
#  3657,
#  2857,
#  1794,
#  351,
#  3632,
#  581,
#  1318,
#  5545,
#  3384,
#  6253,
#  2134,
#  5734,
#  4006,
#  1217,
#  3929,
#  415,
#  563,
#  100,
#  4549,
#  2797,
#  5844,
#  3606,
#  57,
#  6070,
#  137,
#  881,
#  3662,
#  3766,
#  5660,
#  3380,
#  1746,
#  5286,
#  554,
#  4925,
#  4507,
#  5970,
#  1832,
#  4579,
#  3458,
#  116,
#  1393,
#  697,
#  3167,
#  1412,
#  5325,
#  3381,
#  1749,
#  123,
#  2876,
#  3553,
#  2268,
#  5524,
#  3702,
#  895,
#  744,
#  3299,
#  2735,
#  6185,
#  4670,
#  2832,
#  4241,
#  264,
#  4461,
#  3493,
#  154,
#  3614,
#  519,
#  3564,
#  2417,
#  2479,
#  1176,
#  379,
#  6238,
#  2840,
#  948,
#  2394,
#  4075,
#  5468,
#  781,
#  736,
#  3974,
#  4100,
#  1342,
#  2414,
#  2861,
#  1168,
#  5998,
#  2032,
#  6114,
#  2438,
#  2722,
#  2348,
#  4193,
#  3032,
#  3138,
#  1220,
#  4003,
#  6081,
#  5262,
#  1139,
#  468,
#  4319,
#  4256,
#  3343,
#  4109,
#  3507,
#  346,
#  2331,
#  2533,
#  5673,
#  974,
#  6257,
#  3189,
#  2314,
#  2180,
#  1747,
#  2555,
#  1810,
#  2374,
#  4010,
#  3174,
#  4005,
#  3366,
#  4453,
#  1288,
#  1731,
#  1308,
#  6165,
#  103,
#  515,
#  609,
#  5139,
#  5012,
#  877,
#  826,
#  680,
#  2422,
#  76,
#  1118,
#  4177,
#  1164,
#  2463,
#  1664,
#  4170,
#  931,
#  4208,
#  741,
#  2981,
#  1443,
#  6235,
#  496,
#  5507,
#  5083,
#  4481,
#  391,
#  5659,
#  3660,
#  5684,
#  2693,
#  4919,
#  3283,
#  5497,
#  3556,
#  5707,
#  5917,
#  5875,
#  3726,
#  1140,
#  2513,
#  5126,
#  1719,
#  2930,
#  698,
#  3393,
#  2244,
#  6162,
#  3885,
#  5214,
#  1489,
#  5560,
#  3106,
#  2285,
#  5637,
#  5268,
#  696,
#  6116,
#  1062,
#  523,
#  46,
#  2118,
#  4667,
#  897,
#  591,
#  5568,
#  939,
#  4120,
#  3499,
#  5500,
#  1906,
#  1683,
#  5977,
#  1799,
#  372,
#  1174,
#  5378,
#  4626,
#  5448,
#  5857,
#  2743,
#  5775,
#  6151,
#  830,
#  5646,
#  1184,
#  5903,
#  3706,
#  4283,
#  2459,
#  3626,
#  981,
#  1407,
#  1554,
#  433,
#  4510,
#  2378,
#  4979,
#  1576,
#  4920,
#  5186,
#  3038,
#  4097,
#  3184,
#  5896,
#  4665,
#  6194,
#  2229,
#  3115,
#  342,
#  1519,
#  4648,
#  5693,
#  3940,
#  5837,
#  1066,
#  1540,
#  2618,
#  1887,
#  5111,
#  1500,
#  4272,
#  1413,
#  2231,
#  5800,
#  1525,
#  1034,
#  4085,
#  2056,
#  6005,
#  5862,
#  5242,
#  2611,
#  1980,
#  3196,
#  1629,
#  462,
#  64,
#  676,
#  4799,
#  4119,
#  3083,
#  689,
#  1301,
#  1670,
#  973,
#  4327,
#  5015,
#  4674,
#  4754,
#  1626,
#  785,
#  538,
#  1641,
#  3873,
#  5724,
#  856,
#  2748,
#  586,
#  2126,
#  1865,
#  4423,
#  4220,
#  3011,
#  2891,
#  1016,
#  4546,
#  5125,
#  4934,
#  2505,
#  625,
#  788,
#  4995,
#  4211,
#  6097,
#  4445,
#  507,
#  5604,
#  4977,
#  3992,
#  3689,
#  168,
#  3777,
#  2225,
#  5281,
#  386,
#  2102,
#  2584,
#  876,
#  1039,
#  1929,
#  6228,
#  5452,
#  1279,
#  1408,
#  4484,
#  4096,
#  184,
#  1000,
#  1737,
#  4967,
#  545,
#  3904,
#  518,
#  383,
#  6154,
#  4983,
#  5222,
#  343,
#  5614,
#  3436,
#  4617,
#  884,
#  482,
#  2259,
#  2178,
#  1567,
#  219,
#  5831,
#  3698,
#  2752,
#  1136,
#  3850,
#  4081,
#  326,
#  2864,
#  3732,
#  2580,
#  2999,
#  5708,
#  1022,
#  6179,
#  3615,
#  646,
#  2270,
#  2338,
#  4121,
#  5641,
#  733,
#  4580,
#  4390,
#  2388,
#  848,
#  5632,
#  1909,
#  4348,
#  2850,
#  528,
#  2204,
#  4153,
#  5171,
#  2633,
#  2209,
#  4540,
#  1786,
#  377,
#  5674,
#  28,
#  3441,
#  4597,
#  1252,
#  2359,
#  4908,
#  4605,
#  5770,
#  3206,
#  2442,
#  917,
#  648,
#  2701,
#  4483,
#  2202,
#  3804,
#  5194,
#  194,
#  429,
#  589,
#  849,
#  2361,
#  730,
#  3208,
#  611,
#  2523,
#  2632,
#  3194,
#  6163,
#  3855,
#  2445,
#  4960,
#  1550,
#  537,
#  1229,
#  1815,
#  2804,
#  1371,
#  3176,
#  297,
#  3444,
#  5275,
#  620,
#  3496,
#  6174,
#  962,
#  4383,
#  3431,
#  4716,
#  886,
#  5863,
#  4288,
#  261,
#  3075,
#  4309,
#  2012,
#  4785,
#  105,
#  4466,
#  652,
#  1294,
#  5443,
#  4293,
#  5692,
#  3846,
#  6107,
#  2814,
#  1882,
#  4497,
#  2608,
#  780,
#  78,
#  3165,
#  2902,
#  983,
#  4965,
#  2411,
#  5850,
#  2552,
#  5372,
#  4405,
#  5131,
#  3126,
#  388,
#  1084,
#  1035,
#  5505,
#  6027,
#  464,
#  2982,
#  4759,
#  2604,
#  4575,
#  5064,
#  3708,
#  3555,
#  3603,
#  3877,
#  4545,
#  2514,
#  3896,
#  5971,
#  1959,
#  3423,
#  681,
#  2529,
#  1852,
#  1805,
#  2692,
#  5345,
#  3785,
#  3433,
#  1382,
#  3569,
#  5797,
#  5538,
#  1323,
#  229,
#  5960,
#  1858,
#  1145,
#  4699,
#  6056,
#  1726,
#  4356,
#  1950,
#  1497,
#  502,
#  4413,
#  2369,
#  5824,
#  570,
#  702,
#  5758,
#  933,
#  1600,
#  2576,
#  5201,
#  1031,
#  5902,
#  1686,
#  3934,
#  4653,
#  4630,
#  3335,
#  390,
#  3073,
#  2732,
#  4284,
#  3241,
#  1454,
#  475,
#  4735,
#  783,
#  5257,
#  347,
#  4769,
#  2085,
#  483,
#  2253,
#  4926,
#  964,
#  4930,
#  4158,
#  5732,
#  73,
#  300,
#  1420,
#  5180,
#  3030,
#  3254,
#  817,
#  561,
#  2104,
#  3425,
#  2183,
#  4179,
#  155,
#  3504,
#  1873,
#  1171,
#  3704,
#  5778,
#  2301,
#  5586,
#  212,
#  875,
#  2842,
#  950,
#  172,
#  4244,
#  1325,
#  2201,
#  539,
#  3978,
#  775,
#  5198,
#  5978,
#  2872,
#  6157,
#  426,
#  3572,
#  5351,
#  6137,
#  3391,
#  2823,
#  4261,
#  1019,
#  2452,
#  1493,
#  2276,
#  1708,
#  2001,
#  5972,
#  1441,
#  2960,
#  1088,
#  4509,
#  3902,
#  967,
#  3388,
#  2772,
#  5744,
#  4249,
#  3385,
#  5227,
#  5864,
#  2625,
#  1953,
#  4437,
#  5599,
#  1804,
#  5922,
#  4691,
#  1701,
#  3447,
#  4659,
#  2496,
#  5433,
#  5682,
#  3635,
#  2972,
#  1132,
#  3060,
#  4142,
#  3093,
#  463,
#  421,
#  4124,
#  5486,
#  562,
#  1112,
#  6014,
#  235,
#  3599,
#  5905,
#  3340,
#  1884,
#  3107,
#  5364,
#  4207,
#  5763,
#  2393,
#  5203,
#  5079,
#  489,
#  3269,
#  2536,
#  2347,
#  4931,
#  3039,
#  195,
#  749,
#  5027,
#  760,
#  984,
#  442,
#  3276,
#  2283,
#  5748,
#  2207,
#  2751,
#  4757,
#  633,
#  6073,
#  3733,
#  5551,
#  389,
#  3684,
#  3894,
#  82,
#  1109,
#  2619,
#  1619,
#  5781,
#  3843,
#  5496,
#  104,
#  6019,
#  834,
#  5446,
#  2954,
#  3014,
#  4209,
#  457,
#  2430,
#  3334,
#  5529,
#  2569,
#  892,
#  597,
#  3717,
#  705,
#  1841,
#  434,
#  4771,
#  5687,
#  6028,
#  4298,
#  3903,
#  3655,
#  4522,
#  6217,
#  4755,
#  2563,
#  5765,
#  279,
#  3825,
#  1055,
#  883,
#  2974,
#  4891,
#  1469,
#  5026,
#  3329,
#  2408,
#  3342,
#  4753,
#  1696,
#  4710,
#  1284,
#  6060,
#  118,
#  3808,
#  3307,
#  5454,
#  5776,
#  5005,
#  651,
#  5622,
#  161,
#  1470,
#  4990,
#  222,
#  3729,
#  3947,
#  3235,
#  5062,
#  3834,
#  1010,
#  5445,
#  173,
#  5967,
#  6066,
#  2278,
#  4426,
#  1563,
#  2540,
#  3658,
#  1078,
#  5930,
#  896,
#  5085,
#  1277,
#  786,
#  310,
#  1435,
#  4110,
#  206,
#  339,
#  2815,
#  4420,
#  5942,
#  1405,
#  1096,
#  5814,
#  1015,
#  3449,
#  3691,
#  2511,
#  2109,
#  1917,
#  4366,
#  5672,
#  4859,
#  467,
#  2590,
#  4615,
#  1365,
#  3983,
#  6003,
#  272,
#  603,
#  5985,
#  3677,
#  1248,
#  1650,
#  4909,
#  717,
#  3195,
#  5149,
#  5721,
#  1195,
#  1857,
#  493,
#  4257,
#  882,
#  2328,
#  4808,
#  3500,
#  3532,
#  5465,
#  929,
#  978,
#  4657,
#  2129,
#  6074,
#  4088,
#  1869,
#  630,
#  4850,
#  5847,
#  2767,
#  2886,
#  3134,
#  943,
#  4246,
#  4341,
#  1419,
#  1506,
#  4932,
#  2799,
#  1003,
#  671,
#  3926,
#  3369,
#  5774,
#  1124,
#  692,
#  3089,
#  756,
#  618,
#  4167,
#  5410,
#  4511,
#  3442,
#  1606,
#  2846,
#  4357,
#  718,
#  2163,
#  5264,
#  5761,
#  4980,
#  5086,
#  4542,
#  5901,
#  1813,
#  4669,
#  1803,
#  1487,
#  1070,
#  4633,
#  3204,
#  861,
#  3424,
#  1745,
#  5138,
#  2016,
#  2111,
#  6140,
#  1951,
#  4557,
#  4148,
#  808,
#  4140,
#  2351,
#  4161,
#  1360,
#  282,
#  3193,
#  158,
#  4897,
#  1221,
#  1727,
#  4504,
#  5123,
#  1290,
#  5836,
#  3015,
#  5145,
#  4741,
#  2662,
#  1806,
#  2179,
#  727,
#  1862,
#  5974,
#  5359,
#  4355,
#  1936,
#  1856,
#  2596,
#  26,
#  6006,
#  5887,
#  1230,
#  1992,
#  6127,
#  333,
#  5105,
#  3588,
#  575,
#  4933,
#  364,
#  5898,
#  944,
#  4832,
#  1213,
#  2312,
#  2083,
#  3643,
#  2845,
#  550,
#  5597,
#  1110,
#  2173,
#  3407,
#  6079,
#  5464,
#  14,
#  1081,
#  393,
#  5803,
#  4230,
#  3738,
#  2973,
#  4888,
#  3027,
#  1400,
#  3721,
#  995,
#  431,
#  1705,
#  3537,
#  5270,
#  3845,
#  2079,
#  6166,
#  3258,
#  2924,
#  4996,
#  1622,
#  2725,
#  1636,
#  4260,
#  3952,
#  517,
#  2862,
#  926,
#  1734,
#  2167,
#  495,
#  3707,
#  5956,
#  5480,
#  1394,
#  133,
#  4053,
#  5252,
#  277,
#  1219,
#  3765,
#  5812,
#  363,
#  1597,
#  5939,
#  5848,
#  5713,
#  3257,
#  585,
#  3274,
#  3637,
#  1456,
#  ...]

# %%
# Prüfen, ob alle Indizes im erlaubten Bereich sind
print("Max Index in selected_indices:", max(selected_indices))
print("Dataset size:", len(dataset))
# Out:
# Max Index in selected_indices: 6258
# Dataset size: 6259

# %%
filtered_val_dataset = dataset.select(selected_indices)

print("Anzahl der ausgewählten Einträge:", len(filtered_val_dataset))
print(filtered_val_dataset)
# Out:
# Anzahl der ausgewählten Einträge: 2000
# Dataset({
#     features: ['image', 'question', 'answer'],
#     num_rows: 2000
# })

# %%
filtered_val_dataset[0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=792x523>,
#  'question': 'where does this belong to?',
#  'answer': 'endocrine system'}

# %%
sample = filtered_val_dataset[2] 
image = sample["image"] 
question = sample["question"]
answer = sample["answer"]

plt.imshow(image)
plt.axis("off") 
plt.title(f"Q: {question}\nA: {answer}", fontsize=10)
plt.show()

# %%
from hashlib import md5
import numpy as np

def image_to_hash(image):
    img_array = np.array(image)
    img_bytes = img_array.tobytes()
    return md5(img_bytes).hexdigest()

hash_counts = {}
for sample in filtered_val_dataset:
    h = image_to_hash(sample["image"])
    hash_counts[h] = hash_counts.get(h, 0) + 1

# Filtere nur doppelte und sortiere sie absteigend nach Häufigkeit
duplicates = {k: v for k, v in hash_counts.items() if v > 1}
sorted_duplicates = sorted(duplicates.items(), key=lambda x: x[1], reverse=True)

print(f"Anzahl doppelter Bilder: {len(duplicates)}")
print("Top 5 doppelte Bilder (Hash → Vorkommen):")
for h, count in sorted_duplicates[:50]:
    print(f"{h} → {count}x")
# Out:
# C:\Users\Arbnor\Desktop\BA\BA\Bachelor_Arbeit_VQA\venv\Lib\site-packages\PIL\TiffImagePlugin.py:949: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# Anzahl doppelter Bilder: 538
# Top 5 doppelte Bilder (Hash → Vorkommen):
# 0de1ba1702db9367f66004ebfe7dc8a0 → 12x
# cff9167c74756578a96736da83ac3caf → 12x
# e6416a7a6e33321183d6bdbd506a99e3 → 11x
# bebc3a085d642b5329659cfde7493a8a → 10x
# ddd962009981b3c06e1dbc8abc90f08c → 9x
# fe8842649783bfa611df5c102b49ef81 → 9x
# 27fcded16290fef3f1ae49a5d5ad62a4 → 9x
# c7ce99f3fefce4ea6e8a33bea8cc3793 → 9x
# 9a8face4e2186cb43066e227debfc085 → 9x
# ffca083fa03c543ade2bf24e561ff525 → 8x
# 8328aaba170a567ce1d982c90da7b19f → 8x
# dc4beaf2c405f8002830d832044ced6a → 8x
# 9f4be6be36784efeefe96f9b3cbf12d4 → 7x
# eb172866bafc8f22c9f5b2672cae5fbb → 7x
# b64cec0e1018f81713b373eae9bf25c6 → 7x
# e25be99cdf45fe42eb01bd84d30ae43d → 7x
# 33ee59b2984cbd7e47a4cd2b52d38325 → 7x
# acc5f5c929572cb729daccb46830d2b3 → 7x
# 3429127b8eb6440a6b435f06fb96994c → 7x
# bbdba1ae0d54eb6e28ace75c58f6ca88 → 7x
# 1e577624ea00c60ebe76734329297872 → 7x
# f0fad93bd54943826878d88d2de1412c → 7x
# 6b763d0b9eabaa81f834a815e2cc0e8e → 7x
# 55910adaf865b0410262061bd563f2ca → 7x
# 7b071aee85175c91434f827b88d3af15 → 7x
# 8b3dab5ca8bcbc8ecd29392269c46ad1 → 7x
# fe1c0446b02c233d3fb51428f5086df5 → 6x
# a3ad97cdb186d3af54e5e774a5a69650 → 6x
# d4fc82094c5e7fa8eca7ba82fa33ec1c → 6x
# 85edab89f3827b15b78c3dce4a53b9d7 → 6x
# 8de3843093d93fbece26408eb10c28e0 → 6x
# bb73b20762b3a76e2ef3d118ed322332 → 6x
# e819f382d508e3cf9b95f22bc3616fb4 → 6x
# 5cf56c3255125f35e8587e61b88ce465 → 6x
# 0159117d978fbc74d5d70a8d824496cf → 6x
# f50ead955c5c8392043a364b678821c3 → 6x
# 6f4b697ee1c407c1eb63ee8e6c5479cf → 6x
# 46a9dff2aa6fb64022a134b69e2c7db3 → 6x
# 67f9dd1fdd17a6ac0ca74b6d30969e25 → 6x
# 43d9ffdfba0fbb67330f44443e0421be → 6x
# 6f32f4c12950b86db2b624b78650ee27 → 6x
# dd8c8914f4616fa1976ecd6f030e44e3 → 6x
# 12608ca370159b1e0cb6387b54428694 → 6x
# a3701ff8c69141b77b3a5d724f8f84b5 → 6x
# 49b33715cd92d873a16b9d58261a69de → 6x
# f6ebc23ebcc04cd81da2861053cb55cd → 6x
# 6da8ed01e82ef991a9a5d41b215537d1 → 6x
# a19d876186d28da28e80351bcb0a6a15 → 6x
# 2d24615cf79c7e329fd97c8c1c1b2f35 → 5x
# 843951167f13f7323bf4e91723b45e35 → 5x
